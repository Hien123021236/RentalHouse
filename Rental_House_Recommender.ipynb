# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("./data/property.csv")

# %%
df.head()
# Out:
#                                 item_id     deposit  monthly_rent  \
# 0  91c0e569-bddd-4128-9720-2550bb85580e  64800000.0             0
# 1  b00b7919-06be-4d26-98b8-1971787e1d46  72000000.0       4320000
# 2  9eddb6bc-e424-4774-b55f-bfd54366d627  50400000.0       1440000
# 3  12cf6b07-5d56-4126-94d2-ce9cbfe2214f  36000000.0        864000
# 4  929eb20c-3694-46b2-b96c-91117b995d1b  28800000.0       1296000
#
#                           district_uuid  room_qty  unit_area has_elevator  \
# 0  263682f6-d0cd-4569-aeec-e727b76b7665       1.0         42        False
# 1  97c9535e-3985-47ce-a84c-a962c838a76b       2.0        116         True
# 2  b790f536-c274-4147-86e0-94d9b6d7352d       1.0         74        False
# 3  93d06676-4975-4cc5-919b-3a0c29c7ad43       1.0         60         True
# 4  58e59fa9-9947-478f-9cef-bc6a2cbe49a9       1.0         45         True
#
#    building_floor_count  unit_floor has_storage_area  property_age
# 0                   3.0         0.0             True          23.0
# 1                   NaN         1.0             True          16.0
# 2                   2.0         0.0             True          19.0
# 3                   NaN         2.0            False           6.0
# 4                   NaN         1.0             True           4.0

# %%
df.insert(0, 'id', range(1, 1 + len(df)))

# %%
df.head()
# Out:
#    id                               item_id     deposit  monthly_rent  \
# 0   1  91c0e569-bddd-4128-9720-2550bb85580e  64800000.0             0
# 1   2  b00b7919-06be-4d26-98b8-1971787e1d46  72000000.0       4320000
# 2   3  9eddb6bc-e424-4774-b55f-bfd54366d627  50400000.0       1440000
# 3   4  12cf6b07-5d56-4126-94d2-ce9cbfe2214f  36000000.0        864000
# 4   5  929eb20c-3694-46b2-b96c-91117b995d1b  28800000.0       1296000
#
#                           district_uuid  room_qty  unit_area has_elevator  \
# 0  263682f6-d0cd-4569-aeec-e727b76b7665       1.0         42        False
# 1  97c9535e-3985-47ce-a84c-a962c838a76b       2.0        116         True
# 2  b790f536-c274-4147-86e0-94d9b6d7352d       1.0         74        False
# 3  93d06676-4975-4cc5-919b-3a0c29c7ad43       1.0         60         True
# 4  58e59fa9-9947-478f-9cef-bc6a2cbe49a9       1.0         45         True
#
#    building_floor_count  unit_floor has_storage_area  property_age
# 0                   3.0         0.0             True          23.0
# 1                   NaN         1.0             True          16.0
# 2                   2.0         0.0             True          19.0
# 3                   NaN         2.0            False           6.0
# 4                   NaN         1.0             True           4.0

# %%
df.set_index(['id'])
# Out:
#                                    item_id      deposit  monthly_rent  \
# id
# 1     91c0e569-bddd-4128-9720-2550bb85580e   64800000.0             0
# 2     b00b7919-06be-4d26-98b8-1971787e1d46   72000000.0       4320000
# 3     9eddb6bc-e424-4774-b55f-bfd54366d627   50400000.0       1440000
# 4     12cf6b07-5d56-4126-94d2-ce9cbfe2214f   36000000.0        864000
# 5     929eb20c-3694-46b2-b96c-91117b995d1b   28800000.0       1296000
# ...                                    ...          ...           ...
# 4926  6b973986-d910-4d4b-91b0-5192328bb52b    2160000.0        720000
# 4927  fd8f40f5-bb1d-40f6-b8d5-9d2b4dbbef2b  129600000.0       1440000
# 4928  02065751-328d-4f0e-bf50-b35e450b89dc   18000000.0       1296000
# 4929  9c9800b4-280b-48fe-b86d-834509097f19   86400000.0             0
# 4930  609dde7b-ef63-400c-8b0c-746bdb3c999b  108000000.0       1080000
#
#                              district_uuid  room_qty  unit_area has_elevator  \
# id
# 1     263682f6-d0cd-4569-aeec-e727b76b7665       1.0         42        False
# 2     97c9535e-3985-47ce-a84c-a962c838a76b       2.0        116         True
# 3     b790f536-c274-4147-86e0-94d9b6d7352d       1.0         74        False
# 4     93d06676-4975-4cc5-919b-3a0c29c7ad43       1.0         60         True
# 5     58e59fa9-9947-478f-9cef-bc6a2cbe49a9       1.0         45         True
# ...                                    ...       ...        ...          ...
# 4926  3ac48cb3-a697-4d94-a97c-3055f1ad4790       0.0         32        False
# 4927  16d5eea8-f513-4557-b96c-9d861fe4b1af       2.0         98         True
# 4928  fd5ad07f-14b2-4491-aeb3-31651e92e1fd       1.0         63        False
# 4929  c2ab0a0e-c71b-4218-90db-16095a39983e       2.0         63        False
# 4930  402a922d-d082-4d13-8266-2bad33cb537c       1.0         84         True
#
#       building_floor_count  unit_floor has_storage_area  property_age
# id
# 1                      3.0         0.0             True          23.0
# 2                      NaN         1.0             True          16.0
# 3                      2.0         0.0             True          19.0
# 4                      NaN         2.0            False           6.0
# 5                      NaN         1.0             True           4.0
# ...                    ...         ...              ...           ...
# 4926                   NaN         1.0            False          20.0
# 4927                   NaN         2.0             True           7.0
# 4928                   NaN         1.0             True           9.0
# 4929                   4.0         4.0            False          15.0
# 4930                   5.0         3.0            False           6.0
#
# [4930 rows x 11 columns]

# %%
df = df.drop('item_id' , axis = 1)

# %%
df.head()
# Out:
#    id     deposit  monthly_rent                         district_uuid  \
# 0   1  64800000.0             0  263682f6-d0cd-4569-aeec-e727b76b7665
# 1   2  72000000.0       4320000  97c9535e-3985-47ce-a84c-a962c838a76b
# 2   3  50400000.0       1440000  b790f536-c274-4147-86e0-94d9b6d7352d
# 3   4  36000000.0        864000  93d06676-4975-4cc5-919b-3a0c29c7ad43
# 4   5  28800000.0       1296000  58e59fa9-9947-478f-9cef-bc6a2cbe49a9
#
#    room_qty  unit_area has_elevator  building_floor_count  unit_floor  \
# 0       1.0         42        False                   3.0         0.0
# 1       2.0        116         True                   NaN         1.0
# 2       1.0         74        False                   2.0         0.0
# 3       1.0         60         True                   NaN         2.0
# 4       1.0         45         True                   NaN         1.0
#
#   has_storage_area  property_age
# 0             True          23.0
# 1             True          16.0
# 2             True          19.0
# 3            False           6.0
# 4             True           4.0

# %%
df = df.set_index(['id'])

# %%
df.head()
# Out:
#        deposit  monthly_rent                         district_uuid  room_qty  \
# id
# 1   64800000.0             0  263682f6-d0cd-4569-aeec-e727b76b7665       1.0
# 2   72000000.0       4320000  97c9535e-3985-47ce-a84c-a962c838a76b       2.0
# 3   50400000.0       1440000  b790f536-c274-4147-86e0-94d9b6d7352d       1.0
# 4   36000000.0        864000  93d06676-4975-4cc5-919b-3a0c29c7ad43       1.0
# 5   28800000.0       1296000  58e59fa9-9947-478f-9cef-bc6a2cbe49a9       1.0
#
#     unit_area has_elevator  building_floor_count  unit_floor has_storage_area  \
# id
# 1          42        False                   3.0         0.0             True
# 2         116         True                   NaN         1.0             True
# 3          74        False                   2.0         0.0             True
# 4          60         True                   NaN         2.0            False
# 5          45         True                   NaN         1.0             True
#
#     property_age
# id
# 1           23.0
# 2           16.0
# 3           19.0
# 4            6.0
# 5            4.0

# %%
df.columns
# Out:
# Index(['deposit', 'monthly_rent', 'district_uuid', 'room_qty', 'unit_area',
#        'has_elevator', 'building_floor_count', 'unit_floor',
#        'has_storage_area', 'property_age'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4930 entries, 1 to 4930
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   deposit               4925 non-null   float64
#  1   monthly_rent          4930 non-null   int64
#  2   district_uuid         4929 non-null   object
#  3   room_qty              4927 non-null   float64
#  4   unit_area             4930 non-null   int64
#  5   has_elevator          4913 non-null   object
#  6   building_floor_count  3282 non-null   float64
#  7   unit_floor            4893 non-null   float64
#  8   has_storage_area      4920 non-null   object
#  9   property_age          4926 non-null   float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 423.7+ KB

# %%
nan_value = float("NaN")
df.replace("", nan_value, inplace=True)
df.dropna(inplace=True)

# %%
df.head()
# Out:
#        deposit  monthly_rent                         district_uuid  room_qty  \
# id
# 1   64800000.0             0  263682f6-d0cd-4569-aeec-e727b76b7665       1.0
# 3   50400000.0       1440000  b790f536-c274-4147-86e0-94d9b6d7352d       1.0
# 8   25200000.0       1800000  c62e3b32-7b25-4914-9178-8e445194035c       1.0
# 9   21600000.0       1440000  c17ec6fb-7428-4620-b0f3-e23f36513c85       1.0
# 10  86400000.0             0  c17ec6fb-7428-4620-b0f3-e23f36513c85       1.0
#
#     unit_area has_elevator  building_floor_count  unit_floor has_storage_area  \
# id
# 1          42        False                   3.0         0.0             True
# 3          74        False                   2.0         0.0             True
# 8          68        False                   3.0         2.0             True
# 9          68        False                   2.0         2.0            False
# 10         42         True                   4.0         1.0             True
#
#     property_age
# id
# 1           23.0
# 3           19.0
# 8           18.0
# 9           27.0
# 10           0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3266 entries, 1 to 4930
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   deposit               3266 non-null   float64
#  1   monthly_rent          3266 non-null   int64
#  2   district_uuid         3266 non-null   object
#  3   room_qty              3266 non-null   float64
#  4   unit_area             3266 non-null   int64
#  5   has_elevator          3266 non-null   object
#  6   building_floor_count  3266 non-null   float64
#  7   unit_floor            3266 non-null   float64
#  8   has_storage_area      3266 non-null   object
#  9   property_age          3266 non-null   float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 280.7+ KB

# %%
df.head()
# Out:
#        deposit  monthly_rent                         district_uuid  room_qty  \
# id
# 1   64800000.0             0  263682f6-d0cd-4569-aeec-e727b76b7665       1.0
# 3   50400000.0       1440000  b790f536-c274-4147-86e0-94d9b6d7352d       1.0
# 8   25200000.0       1800000  c62e3b32-7b25-4914-9178-8e445194035c       1.0
# 9   21600000.0       1440000  c17ec6fb-7428-4620-b0f3-e23f36513c85       1.0
# 10  86400000.0             0  c17ec6fb-7428-4620-b0f3-e23f36513c85       1.0
#
#     unit_area has_elevator  building_floor_count  unit_floor has_storage_area  \
# id
# 1          42        False                   3.0         0.0             True
# 3          74        False                   2.0         0.0             True
# 8          68        False                   3.0         2.0             True
# 9          68        False                   2.0         2.0            False
# 10         42         True                   4.0         1.0             True
#
#     property_age
# id
# 1           23.0
# 3           19.0
# 8           18.0
# 9           27.0
# 10           0.0

# %%
df =df[df['monthly_rent'] !=0]

# %%
df.head()
# Out:
#        deposit  monthly_rent                         district_uuid  room_qty  \
# id
# 3   50400000.0       1440000  b790f536-c274-4147-86e0-94d9b6d7352d       1.0
# 8   25200000.0       1800000  c62e3b32-7b25-4914-9178-8e445194035c       1.0
# 9   21600000.0       1440000  c17ec6fb-7428-4620-b0f3-e23f36513c85       1.0
# 12  43200000.0       1656000  80aa3b0d-de2b-4703-b6ae-539eaf06f253       2.0
# 14  72000000.0        540000  daf1ac9c-719f-4c56-a264-f1758f071635       2.0
#
#     unit_area has_elevator  building_floor_count  unit_floor has_storage_area  \
# id
# 3          74        False                   2.0         0.0             True
# 8          68        False                   3.0         2.0             True
# 9          68        False                   2.0         2.0            False
# 12         75         True                   5.0         3.0             True
# 14         68        False                   4.0         3.0             True
#
#     property_age
# id
# 3           19.0
# 8           18.0
# 9           27.0
# 12           7.0
# 14          15.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2033 entries, 3 to 4930
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   deposit               2033 non-null   float64
#  1   monthly_rent          2033 non-null   int64
#  2   district_uuid         2033 non-null   object
#  3   room_qty              2033 non-null   float64
#  4   unit_area             2033 non-null   int64
#  5   has_elevator          2033 non-null   object
#  6   building_floor_count  2033 non-null   float64
#  7   unit_floor            2033 non-null   float64
#  8   has_storage_area      2033 non-null   object
#  9   property_age          2033 non-null   float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 174.7+ KB

# %%
features = ["monthly_rent", "room_qty", "unit_area", "unit_floor", "property_age"]

# %%
new_df  = df[features]

# %%
new_df
# Out:
#       monthly_rent  room_qty  unit_area  unit_floor  property_age
# id
# 3          1440000       1.0         74         0.0          19.0
# 8          1800000       1.0         68         2.0          18.0
# 9          1440000       1.0         68         2.0          27.0
# 12         1656000       2.0         75         3.0           7.0
# 14          540000       2.0         68         3.0          15.0
# ...            ...       ...        ...         ...           ...
# 4920       8640000       2.0         89         3.0           7.0
# 4921       2160000       3.0        147         3.0          30.0
# 4922       2592000       2.0         68         2.0           3.0
# 4923       3528000       2.0        100         3.0          12.0
# 4930       1080000       1.0         84         3.0           6.0
#
# [2033 rows x 5 columns]

# %%
new_df.corr()
# Out:
#               monthly_rent  room_qty  unit_area  unit_floor  property_age
# monthly_rent      1.000000  0.147685   0.178438    0.025265     -0.050493
# room_qty          0.147685  1.000000   0.705371    0.115442      0.005003
# unit_area         0.178438  0.705371   1.000000    0.019315      0.079640
# unit_floor        0.025265  0.115442   0.019315    1.000000     -0.187690
# property_age     -0.050493  0.005003   0.079640   -0.187690      1.000000

# %%
sns.heatmap(new_df.corr(), annot=True,cmap='Reds');

# %%
new_df = new_df.drop(columns=['monthly_rent', 'room_qty' ,'unit_area'])

# %%
new_df= new_df.drop_duplicates()
new_df
# Out:
#       unit_floor  property_age
# id
# 3            0.0          19.0
# 8            2.0          18.0
# 9            2.0          27.0
# 12           3.0           7.0
# 14           3.0          15.0
# ...          ...           ...
# 4643        -1.0          14.0
# 4788         6.0          16.0
# 4802         9.0           0.0
# 4812         3.0          23.0
# 4886         6.0          10.0
#
# [226 rows x 2 columns]

# %%
df_scaled = new_df.copy()

# %%
new_df
# Out:
#       unit_floor  property_age
# id
# 3            0.0          19.0
# 8            2.0          18.0
# 9            2.0          27.0
# 12           3.0           7.0
# 14           3.0          15.0
# ...          ...           ...
# 4643        -1.0          14.0
# 4788         6.0          16.0
# 4802         9.0           0.0
# 4812         3.0          23.0
# 4886         6.0          10.0
#
# [226 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df_scaled.values[:] = sc.fit_transform(df_scaled)

# %%
df_scaled
# Out:
#       unit_floor  property_age
# id
# 3      -0.937142      0.160074
# 8      -0.108202      0.083752
# 9      -0.108202      0.770651
# 12      0.306267     -0.755791
# 14      0.306267     -0.145215
# ...          ...           ...
# 4643   -1.351611     -0.221537
# 4788    1.549676     -0.068893
# 4802    2.793085     -1.290046
# 4812    0.306267      0.465362
# 4886    1.549676     -0.526825
#
# [226 rows x 2 columns]

# %%
def Recommender(data):   
    mean = data.mean()
    print("mean")
    print(mean)
    std = data.std()
    print("std")
    print(std)
    array = []
    
    for i, item in data.iterrows():
        check_unit_floor = np.abs(item['unit_floor'] - mean['unit_floor']) <= std['unit_floor'] 
        check_property_age = np.abs(item['property_age'] - mean['property_age']) <= std['property_age'] 
        if (check_unit_floor) & (check_property_age):
            array.append(item)
    
    new_data = pd.DataFrame(array.copy())
    print("Tap muc tieu")
    print(new_data)
    r, c = new_data.shape
    print(r,c)
    unit_floor_max = mean['unit_floor']
    unit_floor_min = mean['unit_floor']
    property_age_max = mean['property_age']
    property_age_min = mean['property_age']
    
    unit_floor_max_point = None
    unit_floor_min_point = None
    property_age_max_point = None
    property_age_min_point = None
    
    
    
    for i,item in new_data.iterrows():
        item['index'] = i
        #get diem bien cua unit_floor
        if ((item['unit_floor'] - mean['unit_floor'] > 0) & (item['unit_floor'] > unit_floor_max)):
            unit_floor_max = item['unit_floor']

        if ((item['unit_floor'] - mean['unit_floor'] < 0) & (item['unit_floor'] < unit_floor_min)):
            unit_floor_min = item['unit_floor']

                   
        #get diem bien cua property_age
        if ((item['property_age'] - mean['property_age'] > 0) & (item['property_age'] > property_age_max)):
            property_age_max = item['property_age']

        if ((item['property_age'] - mean['property_age'] < 0) & (item['property_age'] < property_age_min)):
            property_age_min = item['property_age']

    unit_floor_max_dis_min = float('inf')
    unit_floor_min_dis_min = float('inf')
    property_age_max_dis_min = float('inf')
    property_age_min_dis_min = float('inf')
    
    for i,item in new_data.iterrows():
        unit_floor_max_dis = np.sqrt(np.square(item['unit_floor'] - unit_floor_max) + np.square(item['property_age'] - mean['property_age']))
        if( unit_floor_max_dis < unit_floor_max_dis_min):
            unit_floor_max_dis_min = unit_floor_max_dis
            unit_floor_max_point = new_data.loc[[i]]           
    new_data.drop(unit_floor_max_point.index[0],inplace = True)
    
             
    for i,item in new_data.iterrows():
        unit_floor_min_dis = np.sqrt(np.square(item['unit_floor'] - unit_floor_min)  + np.square(item['property_age'] - mean['property_age']))
        if( unit_floor_min_dis < unit_floor_min_dis_min):
            unit_floor_min_dis_min = unit_floor_min_dis
            unit_floor_min_point = new_data.loc[[i]]
    new_data.drop(unit_floor_min_point.index[0],inplace = True)
        
    for i,item in new_data.iterrows():
        property_age_max_dis = np.sqrt(np.square(item['property_age'] - property_age_max)  + np.square(item['unit_floor'] - mean['unit_floor']))
        if( property_age_max_dis < property_age_max_dis_min):
            property_age_max_dis_min = property_age_max_dis
            property_age_max_point = new_data.loc[[i]]
    new_data.drop(property_age_max_point.index[0],inplace = True)
        
    for i,item in new_data.iterrows():
        property_age_min_dis = np.sqrt(np.square(item['property_age'] - property_age_min)  + np.square(item['unit_floor'] - mean['unit_floor']))
        if( property_age_min_dis < property_age_min_dis_min):
            property_age_min_dis_min = property_age_min_dis
            property_age_min_point = new_data.loc[[i]]
    new_data.drop(property_age_min_point.index[0],inplace = True)   
        
    option_unit_floor = [unit_floor_max_point,unit_floor_min_point]
    option_property_age = [property_age_max_point,property_age_min_point]
        
    
    return pd.DataFrame(array.copy()), option_unit_floor ,option_property_age ,mean

# %%
def UnSelectPoint(data ,mean, unselect_unit_floor_point,unselect_property_age_point):
   
    new_data = data.copy()
    
    #loai 2 diem bien
    new_data.drop(unselect_unit_floor_point.index[0],inplace = True)
    new_data.drop(unselect_property_age_point.index[0],inplace = True)
    
    p1 = unselect_unit_floor_point.iloc[0]
    p2 = unselect_property_age_point.iloc[0]

    # viet pt duong thang
    if((p1['unit_floor'] - p2['unit_floor']) != 0 ):
        a = (p1['property_age'] - p2['property_age'])/(p1['unit_floor'] - p2['unit_floor'])
        b = p1['property_age'] - a*(p1['unit_floor'])
        K = a*mean['unit_floor']+b -mean['property_age']
    
    else:
        return new_data
        
    for i,item in new_data.iterrows():
        f = a*item['unit_floor'] + b - item['property_age']
        #x duong , y am
        if(((item['unit_floor'] >= p2['unit_floor']) & (item['property_age'] <= p1['property_age'])) & (f*K <= 0)):
            new_data =  new_data.drop(i)
        #x duong ,y duong    
        elif(((item['unit_floor'] >= p2['unit_floor']) & (item['property_age'] >= p1['property_age'])) & (f*K <= 0) ):
            new_data =  new_data.drop(i)
            
        #x am , y duong
        elif(((item['unit_floor'] <= p2['unit_floor']) & (item['property_age'] >= p1['property_age'])) & (f*K <= 0) ):
            new_data =  new_data.drop(i)
        
        #x am y am
        elif(((item['unit_floor'] <= p2['unit_floor']) & (item['property_age'] <= p1['property_age'])) & (f*K <= 0)):
            new_data =  new_data.drop(i)
    
    return new_data

# %%
new_df5 = df_scaled.head(30)
new_df5
# Out:
#     unit_floor  property_age
# id
# 3    -0.937142      0.160074
# 8    -0.108202      0.083752
# 9    -0.108202      0.770651
# 12    0.306267     -0.755791
# 14    0.306267     -0.145215
# 18   -0.108202     -0.145215
# 19   -1.351611      0.389040
# 25   -0.108202     -0.374181
# 26   -0.522672     -0.145215
# 27    0.720737      0.618006
# 31   -0.937142     -0.221537
# 33    1.135207     -0.068893
# 34    0.720737     -0.221537
# 35   -0.522672      0.618006
# 36   -0.108202      0.999617
# 38    1.135207     -0.221537
# 39   -0.522672      0.999617
# 42   -0.108202     -0.679469
# 43   -0.108202     -0.221537
# 45   -0.522672     -0.755791
# 47   -0.522672     -0.832114
# 49   -0.522672     -0.297859
# 51   -0.937142     -0.145215
# 52   -0.108202     -0.526825
# 54   -0.522672      0.389040
# 60   -0.937142      0.236396
# 63   -0.522672      0.236396
# 72    0.306267     -0.526825
# 73   -0.522672     -0.374181
# 75    0.306267     -0.297859

# %%
rs,a,b,m = Recommender(new_df5)
print("floor")
print(a[0])
print(a[1])
print("age")
print(b[0])
print(b[1])
# Out:
# mean
# unit_floor     -0.191096
# property_age   -0.048540
# dtype: float64
# std
# unit_floor      0.609921
# property_age    0.502653
# dtype: float64
# Tap muc tieu
#     unit_floor  property_age
# 8    -0.108202      0.083752
# 14    0.306267     -0.145215
# 18   -0.108202     -0.145215
# 25   -0.108202     -0.374181
# 26   -0.522672     -0.145215
# 43   -0.108202     -0.221537
# 49   -0.522672     -0.297859
# 52   -0.108202     -0.526825
# 54   -0.522672      0.389040
# 63   -0.522672      0.236396
# 72    0.306267     -0.526825
# 73   -0.522672     -0.374181
# 75    0.306267     -0.297859
# 13 2
# floor
#     unit_floor  property_age
# 14    0.306267     -0.145215
#     unit_floor  property_age
# 26   -0.522672     -0.145215
# age
#    unit_floor  property_age
# 8   -0.108202      0.083752
#     unit_floor  property_age
# 52   -0.108202     -0.526825

# %%
dt = UnSelectPoint(rs,m,a[1],b[1])
print(dt)
dt.shape
# Out:
#     unit_floor  property_age
# 8    -0.108202      0.083752
# 14    0.306267     -0.145215
# 18   -0.108202     -0.145215
# 25   -0.108202     -0.374181
# 43   -0.108202     -0.221537
# 54   -0.522672      0.389040
# 63   -0.522672      0.236396
# 72    0.306267     -0.526825
# 75    0.306267     -0.297859
# (9, 2)

# %%
# print(new_df.iloc[new_df.index == 9])
# print(new_df.iloc[new_df.index == 34])
# print(new_df.iloc[new_df.index == 36])

# %%
# A = new_df.copy()
# B= new_df5.copy()
# B.loc[(B[:].index).isin(A[:].index), ['unit_floor', 'property_age']] = A[['unit_floor', 'property_age']]
# B

# %%
# import pickle

# %%
# pickle.dump(df_scaled.to_dict() , open('house_dict.pkl' , 'wb'))
# pickle.dump(new_df.to_dict() , open('house.pkl' , 'wb'))
